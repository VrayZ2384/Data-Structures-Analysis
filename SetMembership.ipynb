# %% [markdown]
# # Set Membership

# %% [markdown]
# The cell below defines two **abstract classes**: the first represents a set and basic insert/search operations on it. You will need to impement this API four times, to implement (1) sequential search, (2) binary search tree, (3) balanced search tree, and (4) bloom filter. The second defines the synthetic data generator you will need to implement as part of your experimental framework. <br><br>**Do NOT modify the next cell** - use the dedicated cells further below for your implementation instead. <br>

# %%
# DO NOT MODIFY THIS CELL

from abc import ABC, abstractmethod  

# abstract class to represent a set and its insert/search operations
class AbstractSet(ABC):
    
    # constructor
    @abstractmethod
    def __init__(self):
        pass           
        
    # inserts "element" in the set
    # returns "True" after successful insertion, "False" if the element is already in the set
    # element : str
    # inserted : bool
    @abstractmethod
    def insertElement(self, element):     
        inserted = False
        return inserted   
    
    # checks whether "element" is in the set
    # returns "True" if it is, "False" otherwise
    # element : str
    # found : bool
    @abstractmethod
    def searchElement(self, element):
        found = False
        return found    
    
    
    
# abstract class to represent a synthetic data generator
class AbstractTestDataGenerator(ABC):
    
    # constructor
    @abstractmethod
    def __init__(self):
        pass           
        
    # creates and returns a list of length "size" of strings
    # size : int
    # data : list<str>
    @abstractmethod
    def generateData(self, size):     
        data = [""]*size
        return data

# %% [markdown]
# Use the cell below to define any auxiliary data structure and python function you may need. Leave the implementation of the main API to the next code cells instead.

# %%
# ADD AUXILIARY DATA STRUCTURE DEFINITIONS AND HELPER CODE HERE
from bitarray import bitarray
import timeit

class BinaryTree:

    def __init__(self, element):
        self.element = element
        self.left = None
        self.right = None

class Node():
    def __init__(self, key, color):
        self.key = key
        self.left = None 
        self.right = None 
        #黑色为false，红色为true
        self.color = color 
        
    def searchElement(self, element):     
        found = False
        if self.key == element:
            found = True
        elif element < self.key and self.left:
            return self.left.searchElement(element)
        elif element > self.key and self.right:
            return self.right.searchElement(element)
        return found    
    
    def insertElement(self, element):
        return self.put(self, element)
    
    def put(self, n, element):
        inserted = False
        if element == n.key:
            inserted = False
        elif element < n.key:
            if n.left is None:
                n.left = Node(element, True)
                inserted = True
            else:
                inserted, n.left = self.put(n.left, element)
        elif element > n.key:
            if n.right is None:
                n.right = Node(element, True)
                inserted = True
            else:
                inserted, n.right = self.put(n.right, element)

        if self.isRed(n.right) and self.isRed(n.left) == False:
            n = self.rotateLeft(n)
        if self.isRed(n.left) and self.isRed(n.left.left):
            n = self.rotateRight(n)
        if self.isRed(n.right) and self.isRed(n.left):
            n = self.flipColor(n)
        return inserted, n

    
    def rotateLeft(self, n):
        x = n.right
        n.right = x.left
        x.left = n
        x.color = n.color
        n.color = True
        return x

    def rotateRight(self, n):
        x = n.left
        n.left = x.right
        x.right = n
        x.color = n.color
        n.color = True
        return x

    def flipColor(self, n):
        n.color = True
        n.left.color = False
        n.right.color = False
        return n
        
    def isRed(self, n):
        if n is None:
            return False
        return n.color
    
def merge(a, b):
    i = 0 
    j = 0
    result = []
    while i < len(a) and j < len(b):
        if a[i] < b[j]:
            result.append(a[i])
            i += 1
        else:
            result.append(b[j])
            j += 1
    if i < len(a):
        for k in range(i, len(a)):
            result.append(a[k])
    else:
        for k in range(j, len(b)):
            result.append(b[k])
    return result

def mergesort(list):
    mid = len(list) // 2
    if mid == 0:
        return list
    return merge(mergesort(list[:mid]), mergesort(list[mid:])) 

def nearestLowerPrime(x):
    if(x < 2):
        return -1
    x += 1
    isPrime = [True]*x
    closestPrime = 2
    for i in range(2, x):
        if isPrime[i]:
            for j in range(2*i, x, i):
                isPrime[j] = False
            closestPrime = i
    return closestPrime

def measureTime(func, setImplementation, data):
    starting_time = timeit.default_timer()
    func(setImplementation, data)
    end_time = timeit.default_timer()
    return end_time - starting_time

def insertion(set_implementation, insert_data):
    if(type(set_implementation) == BloomFilterSet):
        set_implementation.setArraySize(len(insert_data))
    for i in insert_data:
        set_implementation.insertElement(i)
        
def search(set_implementation, search_data):
    for i in search_data:
        set_implementation.searchElement(i)
        

def searchChecker(set_implementation, search_data):
    inSet = []
    for i in search_data:
        inSet.append(set_implementation.searchElement(i))
    return inSet


def extractRealData(fileName, searchFile = False):
    data = []
    for line in open(fileName, 'r'):
        if searchFile:
            data.append(line.strip())
        else:
            data += line.split(" ")
    return data

def checkFpr(bloomFilter, insertData, searchData):
    correctImplementation = BalancedSearchTreeSet()
    insertion(correctImplementation, insertData)
    fpr = falsePositiveRate(searchChecker(bloomFilter, searchData), searchChecker(correctImplementation, searchData))
    print("False positive rate is: ", fpr)

#Tests time taken on different number of strings:
def generate_1():
    testing_size = [5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
    result = []
    data = TestDataGenerator().generateData(max(testing_size), 5, 10)
    for i in testing_size:
        result.append(data[:i])
    return result

def synthetic_1(set_implementation):
    for i in generate_1():
        if(type(set_implementation) == SequentialSearchSet):
            if len(i) > 100000:
                continue
        print("Time taken for insertion:", measureTime(insertion,set_implementation, i), "at size", len(i))
        print("Time taken for search:", measureTime(search,set_implementation, i), "at size", len(i))
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)
            

#Tests time taken with different orders: ascending, descending, random
def generate_2():
    test_data_random = TestDataGenerator().generateData(100000, 5, 10)
    test_data_ascending = mergesort(test_data_random)
    test_data_descending = test_data_ascending[::-1]
    return [test_data_ascending, test_data_descending, test_data_random]

def synthetic_2(set_implementation):
    order = ["ascending order", "descending order", "random order"]
    j = 0
    for i in generate_2():
        print("Time taken for insertion:", measureTime(insertion,set_implementation, i), "at", order[j])
        print("Time taken for search:", measureTime(search,set_implementation, i), "at", order[j])
        j += 1
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)


#Tests time taken with strings of different length

def generate_3():
    testing_size = [(3,8), (5,10), (10,15), (15,20), (20,25), (30,35), (40,45)]
    result = []
    for i in testing_size:
        result.append(TestDataGenerator().generateData(100000, i[0], i[1]))
    return result


def synthetic_3(set_implementation):
    testing_size = [(3,8), (5,10), (10,15), (15,20), (20,25), (30,35), (40,45)]
    j = 0
    for i in generate_3():
        print("Time taken for insertion:", measureTime(insertion,set_implementation, i),"at string length", testing_size[j][0], "to", testing_size[j][1])
        print("Time taken for search:", measureTime(search,set_implementation, i), "at string length", testing_size[j][0], "to", testing_size[j][1])
        j += 1
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)

#Tests time taken with different proportions of duplicates
def generate_4():
    duplicate_number = [0, 10000, 20000, 30000, 40000, 50000]
    non_duplicate_number = [100000, 80000, 60000, 40000, 20000, 0]
    data = TestDataGenerator().generateData(100000, 5, 10)
    dulplicate_data = TestDataGenerator().generateData(50000, 5, 10)
    result = []
    for i in range(len(duplicate_number)):
        combined = data[:non_duplicate_number[i]] + dulplicate_data[:duplicate_number[i]]* 2
        random.shuffle(combined)
        result.append(combined)
    return result

def synthetic_4(set_implementation):
    non_duplicate_number = [100000, 80000, 60000, 40000, 20000, 0]
    j = 0
    for i in generate_4():
        print("Time taken for insertion:", measureTime(insertion,set_implementation, i),"at duplicate proportion", (100000 - non_duplicate_number[j])/100000)
        print("Time taken for search:", measureTime(search,set_implementation, i), "at duplicate proportion", (100000 - non_duplicate_number[j])/100000)
        j += 1
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)
        

#Tests time taken with different percentage of none values
def generate_5():
    empty_number = [0, 500, 1000, 5000, 10000, 15000, 20000, 30000, 40000]
    data = TestDataGenerator().generateData(100000, 5, 10)
    result = []
    for i in range(len(empty_number)):
        combined = data[:100000-empty_number[i]] + [None] * empty_number[i]
        random.shuffle(combined)
        result.append(combined)
    return result

def synthetic_5(set_implementation):
    empty_number = [0, 500, 1000, 5000, 10000, 15000, 20000, 30000, 40000]
    j = 0
    for i in generate_5():
        print("Time taken for insertion:", measureTime(insertion,set_implementation, i),"at empty number", empty_number[j])
        print("Time taken for search:", measureTime(search,set_implementation, i), "at empty number", empty_number[j])
        j += 1
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)
        
#Tests time taken in seaching values not in the set
def generate_6():
    absent_number = [0,20000,40000,60000,80000,100000]
    insert_data = TestDataGenerator().generateData(100000, 5, 10)
    search_data = TestDataGenerator().generateData(100000, 5, 10)
    result = []
    for i in range(len(absent_number)):
        combined = insert_data[:100000-absent_number[i]] + search_data[:absent_number[i]]
        random.shuffle(combined)
        result.append(combined)
    return insert_data, result

def synthetic_6(set_implementation):
    absent_number = [0,20000,40000,60000,80000,100000]
    j = 0
    insert, searches = generate_6()
    insertion(set_implementation, insert)
    for i in searches:
        print("Time taken for search:", measureTime(search,set_implementation, i), "at searching absent number", absent_number[j])
        j += 1
        if(type(set_implementation) == BloomFilterSet):
            checkFpr(set_implementation, i,i)

def blockSeperator():
    print('-'*88)    

def ceil(x):
    y = int(x)
    if y - x > 0:
        return y + 1
    else:
        return y
    
def falsePositiveRate(bfResults, correctResults ):
    correct = 0
    positive = 0
    for i in range(len(bfResults)):
        if bfResults[i]:
            positive += 1
            if bfResults[i] == correctResults[i]:
                correct += 1
    return (positive - correct) /positive

# %% [markdown]
# Use the cell below to implement the requested API by means of **sequential search**.

# %%
class SequentialSearchSet(AbstractSet):
    
    def __init__(self):
        # ADD YOUR CODE HERE
        self.elements = []
        pass       
    
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
        if self.searchElement(element) == False: #insert element if element is not in set
            self.elements.append(element)
            return True
        return inserted
    
    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE
        for i in self.elements:
            if i==element:
                result = True
                break
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **binary search tree**.

# %%
class BinarySearchTreeSet(AbstractSet):
    def __init__(self):
        self.root = None

    def insertElement(self, element):
        inserted = False

        new_node = BinaryTree(element)

        if self.root is None:
            self.root = new_node
            inserted = True
        else:
            currentNode = self.root
            while currentNode:
                if element == currentNode.element:
                    return False
                elif element < currentNode.element:
                    if currentNode.left:
                        currentNode = currentNode.left
                    else:
                        currentNode.left = new_node
                        inserted = True
                        break
                else:
                    if currentNode.right:
                        currentNode = currentNode.right
                    else:
                        currentNode.right = new_node
                        inserted = True
                        break

        return inserted

    def searchElement(self, element):
        found = False
        currentNode = self.root

        while currentNode:
            if element == currentNode.element:
                found = True
                break
            elif element < currentNode.element:
                currentNode = currentNode.left
            else:
                currentNode = currentNode.right

        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **balanced search tree**.

# %%
class BalancedSearchTreeSet(AbstractSet):
    def __init__(self):
        self.node = None
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
        if element == None:
            return False
        if self.node == None:
            self.node = Node(element, True)
        inserted, self.node = self.node.insertElement(element) 
        return inserted

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE
        if element == None:
            return False
        return self.node.searchElement(element)

# %% [markdown]
# Use the cell below to implement the requested API by means of **bloom filter**.

# %%
class BloomFilterSet(AbstractSet):

    def setArraySize(self, n = 500000):
        self.n = n
        #Given optimal values with 1% estimated false positive rate, As math log function couldn't be used to 
        #to calculate array size at different false positive rates.
        self.m = nearestLowerPrime(int(ceil(n*4.60517018599)/1.12068498637))
        self.store = bitarray(self.m)
        self.store.setall(0)
        self.k = round((self.m/self.n)*0.69314718056)

    def __init__(self):
        # ADD YOUR CODE HERE
        self.setArraySize()
        pass    
    
    def polynomial_hashing(self, key):
        indices = []
        primes = [2, 3, 5, 7, 9, 11, 13, 17, 23, 29, 31, 37] 
        for i in primes[-(self.k):]:
            hashVal = 0 
            for j in range(len(key)):
                hashVal = ((i**j)*ord(key[j]) + hashVal) % self.m
            indices.append(hashVal)
        return indices

    def insertElement(self, element):
        inserted = True
        for i in self.polynomial_hashing(element):
            inserted = self.store[i] and inserted
            self.store[i] = 1
        return inserted

    def searchElement(self, element):
        found = True
        # ADD YOUR CODE HERE

        for i in self.polynomial_hashing(element):
            found = self.store[i] and found
        return found

# %% [markdown]
# Use the cell below to implement the **synthetic data generator** as part of your experimental framework.

# %%
import string
import random

class TestDataGenerator(AbstractTestDataGenerator):
    
    def __init__(self):
        # ADD YOUR CODE HERE
        pass           
    
    def generateData(self, size, m, n):     
        # ADD YOUR CODE HERE
        data = [""]*size
        for i in range(size):
            data[i] = ''.join(random.choices(string.ascii_letters, k = random.randint(m, n)))
        return data

# %% [markdown]
# Use the cells below for the python code needed to **fully evaluate your implementations**, first on real data and subsequently on synthetic data (i.e., read data from test files / generate synthetic one, instantiate each of the 4 set implementations in turn, then thorouhgly experiment with insert/search operations and measure their performance).

# %%
import timeit

# ADD YOUR TEST CODE HERE TO WORK ON REAL DATA
#list of implementations 
implementations = [SequentialSearchSet, BinarySearchTreeSet, BalancedSearchTreeSet, BloomFilterSet]

def realDataTesting(setImplementation):
    fileNames = ["test1-mobydick.txt", "test2-warpeace.txt", "test3-dickens.txt"]
    searchData = extractRealData('test-search.txt', True)
    for fileName in fileNames: 
        curSetImplementation = setImplementation()
        insertData = extractRealData(fileName)
        insertionTime = measureTime(insertion, curSetImplementation, insertData)
        searchTime = measureTime(search, curSetImplementation, searchData)
        print("For ", fileName, " insertion takes ", insertionTime, " search takes ", searchTime)
        if(setImplementation == BloomFilterSet):
            checkFpr(curSetImplementation, insertData, searchData)
        
for implementation in implementations:
    blockSeperator()
    print('For ', implementation.__name__)
    realDataTesting(implementation)
    blockSeperator()
# Out:
# ----------------------------------------------------------------------------------------
# For  SequentialSearchSet
# For  test1-mobydick.txt  insertion takes  54.68688523699893  search takes  0.40170400600072753
# For  test2-warpeace.txt  insertion takes  190.7388286150017  search takes  0.8205282589988201
# For  test3-dickens.txt  insertion takes  10250.786859342  search takes  3.7289743779983837
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# For  BinarySearchTreeSet
# For  test1-mobydick.txt  insertion takes  0.36057316300139064  search takes  0.0007565340019937139
# For  test2-warpeace.txt  insertion takes  0.9132081190000463  search takes  0.0007906690007075667
# For  test3-dickens.txt  insertion takes  8.429955895000603  search takes  0.0008362949993170332
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# For  BalancedSearchTreeSet
# For  test1-mobydick.txt  insertion takes  1.3121696089983743  search takes  0.0012362679990474135
# For  test2-warpeace.txt  insertion takes  3.3869937529998424  search takes  0.0011916240000573453
# For  test3-dickens.txt  insertion takes  34.90593213399916  search takes  0.0014427470014197752
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# For  BloomFilterSet
# For  test1-mobydick.txt  insertion takes  1.013036601998465  search takes  0.0028331040011835285
# False positive rate is:  0.0
# For  test2-warpeace.txt  insertion takes  2.79907238099986  search takes  0.002856377999705728
# False positive rate is:  0.0
# For  test3-dickens.txt  insertion takes  25.87033645200063  search takes  0.0028848010006186087
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------

# %%
import timeit

# ADD YOUR TEST CODE HERE TO WORK ON SYNTHETIC DATA
tests = [
    (synthetic_1, 'different number of strings'),
    (synthetic_2, 'different orders: ascending, descending, random'),
    (synthetic_3, 'strings of different lengths'),
    (synthetic_4, 'different proportions of duplicates'),
    (synthetic_6, 'search values that are not in the set')
]

"""tests is a list of tuples with test[0] being the testing function and test[1] being a string explaining 
what is being tested"""

for test in tests:
    for implementation in implementations:
        blockSeperator()
        print('Time taken with ', test[1], 'for ', implementation.__name__ , ':')
        test[0](implementation())
        blockSeperator()
# Out:
# ----------------------------------------------------------------------------------------
# Time taken with  different number of strings for  SequentialSearchSet :
# Time taken for insertion: 9.647999831940979e-06 at size 5
# Time taken for search: 2.273998688906431e-06 at size 5
# Time taken for insertion: 1.4447003195527941e-05 at size 10
# Time taken for search: 2.805998519761488e-06 at size 10
# Time taken for insertion: 4.7048000851646066e-05 at size 50
# Time taken for search: 3.860200013150461e-05 at size 50
# Time taken for insertion: 0.00017961800040211529 at size 100
# Time taken for search: 0.00016404899724875577 at size 100
# Time taken for insertion: 0.003528383000229951 at size 500
# Time taken for search: 0.0038301919994410127 at size 500
# Time taken for insertion: 0.016014381999411853 at size 1000
# Time taken for search: 0.015826608996576397 at size 1000
# Time taken for insertion: 0.3514899619985954 at size 5000
# Time taken for search: 0.3501837340008933 at size 5000
# Time taken for insertion: 1.667050949003169 at size 10000
# Time taken for search: 1.6641624479998427 at size 10000
# Time taken for insertion: 36.80132828200294 at size 50000
# Time taken for search: 36.84767165700032 at size 50000
# Time taken for insertion: 195.2114685460001 at size 100000
# Time taken for search: 194.66760176599928 at size 100000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different number of strings for  BinarySearchTreeSet :
# Time taken for insertion: 1.7112000932684168e-05 at size 5
# Time taken for search: 3.50600021192804e-06 at size 5
# Time taken for insertion: 8.304999937536195e-06 at size 10
# Time taken for search: 3.837001713691279e-06 at size 10
# Time taken for insertion: 6.232800296857022e-05 at size 50
# Time taken for search: 2.8002999897580594e-05 at size 50
# Time taken for insertion: 0.00011275299766566604 at size 100
# Time taken for search: 6.823900184826925e-05 at size 100
# Time taken for insertion: 0.01604758000030415 at size 500
# Time taken for search: 0.00048295899978256784 at size 500
# Time taken for insertion: 0.0016022870004235301 at size 1000
# Time taken for search: 0.0010833189990080427 at size 1000
# Time taken for insertion: 0.010297886001353618 at size 5000
# Time taken for search: 0.006968388999666786 at size 5000
# Time taken for insertion: 0.02157409400024335 at size 10000
# Time taken for search: 0.01556990099925315 at size 10000
# Time taken for insertion: 0.2018952439975692 at size 50000
# Time taken for search: 0.12003017099777935 at size 50000
# Time taken for insertion: 0.4421212259985623 at size 100000
# Time taken for search: 0.3045225429996208 at size 100000
# Time taken for insertion: 3.7996383319987217 at size 500000
# Time taken for search: 2.29786188000071 at size 500000
# Time taken for insertion: 7.694277272999898 at size 1000000
# Time taken for search: 5.335815761998674 at size 1000000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different number of strings for  BalancedSearchTreeSet :
# Time taken for insertion: 3.110900070169009e-05 at size 5
# Time taken for search: 5.491001502377912e-06 at size 5
# Time taken for insertion: 2.1500000002561137e-05 at size 10
# Time taken for search: 5.35999788553454e-06 at size 10
# Time taken for insertion: 0.0001728349998302292 at size 50
# Time taken for search: 3.912300235242583e-05 at size 50
# Time taken for insertion: 0.00036906400055158883 at size 100
# Time taken for search: 9.24239975574892e-05 at size 100
# Time taken for insertion: 0.02091083599952981 at size 500
# Time taken for search: 0.0006393730000127107 at size 500
# Time taken for insertion: 0.005542123002669541 at size 1000
# Time taken for search: 0.001435401998605812 at size 1000
# Time taken for insertion: 0.05376097699991078 at size 5000
# Time taken for search: 0.009039456999744289 at size 5000
# Time taken for insertion: 0.07505088499965495 at size 10000
# Time taken for search: 0.020087695997062838 at size 10000
# Time taken for insertion: 0.5047790780008654 at size 50000
# Time taken for search: 0.14801233600155683 at size 50000
# Time taken for insertion: 1.1503487069967377 at size 100000
# Time taken for search: 0.35848053700101445 at size 100000
# Time taken for insertion: 10.184118944001966 at size 500000
# Time taken for search: 2.487903452001774 at size 500000
# Time taken for insertion: 20.875962571000855 at size 1000000
# Time taken for search: 5.670360834999883 at size 1000000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different number of strings for  BloomFilterSet :
# Time taken for insertion: 9.66320003499277e-05 at size 5
# Time taken for search: 4.116800118936226e-05 at size 5
# False positive rate is:  0.0
# Time taken for insertion: 7.762599852867424e-05 at size 10
# Time taken for search: 6.774799840059131e-05 at size 10
# False positive rate is:  0.0
# Time taken for insertion: 0.00038221000068006106 at size 50
# Time taken for search: 0.000350449001416564 at size 50
# False positive rate is:  0.0
# Time taken for insertion: 0.0007946160003484692 at size 100
# Time taken for search: 0.000744061002478702 at size 100
# False positive rate is:  0.0
# Time taken for insertion: 0.003953491999709513 at size 500
# Time taken for search: 0.0037377070002548862 at size 500
# False positive rate is:  0.0
# Time taken for insertion: 0.0077213850017869845 at size 1000
# Time taken for search: 0.007227786001749337 at size 1000
# False positive rate is:  0.0
# Time taken for insertion: 0.03816784100126824 at size 5000
# Time taken for search: 0.03573486100140144 at size 5000
# False positive rate is:  0.0
# Time taken for insertion: 0.07654088800336467 at size 10000
# Time taken for search: 0.07101609899837058 at size 10000
# False positive rate is:  0.0
# Time taken for insertion: 0.37997382400135393 at size 50000
# Time taken for search: 0.35461841100186575 at size 50000
# False positive rate is:  0.0
# Time taken for insertion: 0.7558951169994543 at size 100000
# Time taken for search: 0.7051808469987009 at size 100000
# False positive rate is:  0.0
# Time taken for insertion: 3.8970759930016357 at size 500000
# Time taken for search: 3.505806962999486 at size 500000
# False positive rate is:  0.0
# Time taken for insertion: 7.8531054300001415 at size 1000000
# Time taken for search: 7.061410199999955 at size 1000000
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different orders: ascending, descending, random for  SequentialSearchSet :
# Time taken for insertion: 362.07409390999965 at ascending order
# Time taken for search: 359.13545394299945 at ascending order
# Time taken for insertion: 359.6888722270014 at descending order
# Time taken for search: 362.1658238579985 at descending order
# Time taken for insertion: 373.7985022540015 at random order
# Time taken for search: 373.3231628180001 at random order
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different orders: ascending, descending, random for  BinarySearchTreeSet :
# Time taken for insertion: 955.1502387699984 at ascending order
# Time taken for search: 860.6200377880014 at ascending order
# Time taken for insertion: 955.2199355439989 at descending order
# Time taken for search: 860.6361650139988 at descending order
# Time taken for insertion: 955.9409562950023 at random order
# Time taken for search: 860.9183603990023 at random order
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different orders: ascending, descending, random for  BalancedSearchTreeSet :
# Time taken for insertion: 1.0548268639977323 at ascending order
# Time taken for search: 0.2537943520001136 at ascending order
# Time taken for insertion: 0.8107801420010219 at descending order
# Time taken for search: 0.2545085759993526 at descending order
# Time taken for insertion: 1.0630363279997255 at random order
# Time taken for search: 0.3931198999998742 at random order
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different orders: ascending, descending, random for  BloomFilterSet :
# Time taken for insertion: 0.7650410169990209 at ascending order
# Time taken for search: 0.7054532969996217 at ascending order
# False positive rate is:  0.0
# Time taken for insertion: 0.7643747790025373 at descending order
# Time taken for search: 0.7067917710010079 at descending order
# False positive rate is:  0.0
# Time taken for insertion: 0.759728573000757 at random order
# Time taken for search: 0.7021329999988666 at random order
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  strings of different lengths for  SequentialSearchSet :
# Time taken for insertion: 135.9698528450026 at string length 3 to 8
# Time taken for search: 135.81964602399967 at string length 3 to 8
# Time taken for insertion: 481.25007163699775 at string length 5 to 10
# Time taken for search: 481.37106473099993 at string length 5 to 10
# Time taken for insertion: 761.5259802789988 at string length 10 to 15
# Time taken for search: 761.8102604939995 at string length 10 to 15
# Time taken for insertion: 985.4477765859992 at string length 15 to 20
# Time taken for search: 985.7612067490008 at string length 15 to 20
# Time taken for insertion: 1154.2765288899973 at string length 20 to 25
# Time taken for search: 1154.7337690319982 at string length 20 to 25
# Time taken for insertion: 1332.8056081390023 at string length 30 to 35
# Time taken for search: 1329.8688737649936 at string length 30 to 35
# Time taken for insertion: 1508.3545499430038 at string length 40 to 45
# Time taken for search: 1509.249036248002 at string length 40 to 45
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  strings of different lengths for  BinarySearchTreeSet :
# Time taken for insertion: 0.5081647289989633 at string length 3 to 8
# Time taken for search: 0.30457684200519 at string length 3 to 8
# Time taken for insertion: 0.7363218370010145 at string length 5 to 10
# Time taken for search: 0.43866168100066716 at string length 5 to 10
# Time taken for insertion: 0.9244105209945701 at string length 10 to 15
# Time taken for search: 0.4889243060024455 at string length 10 to 15
# Time taken for insertion: 0.8783430589974159 at string length 15 to 20
# Time taken for search: 0.5271785660006572 at string length 15 to 20
# Time taken for insertion: 0.9728982080050628 at string length 20 to 25
# Time taken for search: 0.5534303930035094 at string length 20 to 25
# Time taken for insertion: 0.7028296179996687 at string length 30 to 35
# Time taken for search: 0.5750509650024469 at string length 30 to 35
# Time taken for insertion: 1.108493569001439 at string length 40 to 45
# Time taken for search: 0.5924460669994005 at string length 40 to 45
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  strings of different lengths for  BalancedSearchTreeSet :
# Time taken for insertion: 1.292875537998043 at string length 3 to 8
# Time taken for search: 0.3581766470015282 at string length 3 to 8
# Time taken for insertion: 1.8855182059996878 at string length 5 to 10
# Time taken for search: 0.44530941900302423 at string length 5 to 10
# Time taken for insertion: 2.2492109630038613 at string length 10 to 15
# Time taken for search: 0.48619485199742485 at string length 10 to 15
# Time taken for insertion: 2.6371605540043674 at string length 15 to 20
# Time taken for search: 0.5165545370036853 at string length 15 to 20
# Time taken for insertion: 2.412720159998571 at string length 20 to 25
# Time taken for search: 0.5376633170017158 at string length 20 to 25
# Time taken for insertion: 2.579272360999312 at string length 30 to 35
# Time taken for search: 0.5590144520028844 at string length 30 to 35
# Time taken for insertion: 2.7846792839991394 at string length 40 to 45
# Time taken for search: 0.5775650569994468 at string length 40 to 45
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  strings of different lengths for  BloomFilterSet :
# Time taken for insertion: 0.5669690499998978 at string length 3 to 8
# Time taken for search: 0.5140267110036802 at string length 3 to 8
# False positive rate is:  0.0
# Time taken for insertion: 0.7623194980042172 at string length 5 to 10
# Time taken for search: 0.7061733130030916 at string length 5 to 10
# False positive rate is:  0.0
# Time taken for insertion: 1.2908451040057116 at string length 10 to 15
# Time taken for search: 1.2325984240014805 at string length 10 to 15
# False positive rate is:  0.0
# Time taken for insertion: 1.8768332410036237 at string length 15 to 20
# Time taken for search: 1.7980128810013412 at string length 15 to 20
# False positive rate is:  0.0
# Time taken for insertion: 2.4419605289949686 at string length 20 to 25
# Time taken for search: 2.3908481649996247 at string length 20 to 25
# False positive rate is:  0.0
# Time taken for insertion: 3.7696655959953205 at string length 30 to 35
# Time taken for search: 3.7261484039991046 at string length 30 to 35
# False positive rate is:  0.0
# Time taken for insertion: 5.172351815002912 at string length 40 to 45
# Time taken for search: 5.162366700002167 at string length 40 to 45
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different proportions of duplicates for  SequentialSearchSet :
# Time taken for insertion: 361.2468166369945 at duplicate proportion 0.0
# Time taken for search: 360.0664359520015 at duplicate proportion 0.0
# Time taken for insertion: 513.8616177079966 at duplicate proportion 0.2
# Time taken for search: 514.584256323993 at duplicate proportion 0.2
# Time taken for insertion: 802.9447988550019 at duplicate proportion 0.4
# Time taken for search: 802.5504934380006 at duplicate proportion 0.4
# Time taken for insertion: 1229.1684728870023 at duplicate proportion 0.6
# Time taken for search: 1228.5257713579995 at duplicate proportion 0.6
# Time taken for insertion: 1755.5385849140002 at duplicate proportion 0.8
# Time taken for search: 1754.9528456469998 at duplicate proportion 0.8
# Time taken for insertion: 2377.3312474039994 at duplicate proportion 1.0
# Time taken for search: 2373.1939529199954 at duplicate proportion 1.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different proportions of duplicates for  BinarySearchTreeSet :
# Time taken for insertion: 0.5924524610018125 at duplicate proportion 0.0
# Time taken for search: 0.36990421600057743 at duplicate proportion 0.0
# Time taken for insertion: 0.4724054870021064 at duplicate proportion 0.2
# Time taken for search: 0.3986743210043642 at duplicate proportion 0.2
# Time taken for insertion: 0.496099789001164 at duplicate proportion 0.4
# Time taken for search: 0.42037422499561217 at duplicate proportion 0.4
# Time taken for insertion: 0.5192820689990185 at duplicate proportion 0.6
# Time taken for search: 0.44366518799506593 at duplicate proportion 0.6
# Time taken for insertion: 0.6410957659973064 at duplicate proportion 0.8
# Time taken for search: 0.4674172900049598 at duplicate proportion 0.8
# Time taken for insertion: 0.5732664039969677 at duplicate proportion 1.0
# Time taken for search: 0.49310600200260524 at duplicate proportion 1.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different proportions of duplicates for  BalancedSearchTreeSet :
# Time taken for insertion: 1.455916534003336 at duplicate proportion 0.0
# Time taken for search: 0.3883012520018383 at duplicate proportion 0.0
# Time taken for insertion: 1.2467988670032355 at duplicate proportion 0.2
# Time taken for search: 0.4396630959963659 at duplicate proportion 0.2
# Time taken for insertion: 1.2835153199994238 at duplicate proportion 0.4
# Time taken for search: 0.4505035850015702 at duplicate proportion 0.4
# Time taken for insertion: 1.5021215949964244 at duplicate proportion 0.6
# Time taken for search: 0.464801993999572 at duplicate proportion 0.6
# Time taken for insertion: 1.3641068529977929 at duplicate proportion 0.8
# Time taken for search: 0.4774407830045675 at duplicate proportion 0.8
# Time taken for insertion: 1.3938883390001138 at duplicate proportion 1.0
# Time taken for search: 0.49380831299640704 at duplicate proportion 1.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  different proportions of duplicates for  BloomFilterSet :
# Time taken for insertion: 0.7692267269958393 at duplicate proportion 0.0
# Time taken for search: 0.7099385519977659 at duplicate proportion 0.0
# False positive rate is:  0.0
# Time taken for insertion: 0.7665010040000197 at duplicate proportion 0.2
# Time taken for search: 0.7140547210001387 at duplicate proportion 0.2
# False positive rate is:  0.0
# Time taken for insertion: 0.7649562599981437 at duplicate proportion 0.4
# Time taken for search: 0.7146505409982638 at duplicate proportion 0.4
# False positive rate is:  0.0
# Time taken for insertion: 0.7614037719977205 at duplicate proportion 0.6
# Time taken for search: 0.7161180210023304 at duplicate proportion 0.6
# False positive rate is:  0.0
# Time taken for insertion: 0.7611030569969444 at duplicate proportion 0.8
# Time taken for search: 0.7090503139988868 at duplicate proportion 0.8
# False positive rate is:  0.0
# Time taken for insertion: 0.7617544120003004 at duplicate proportion 1.0
# Time taken for search: 0.7078065259993309 at duplicate proportion 1.0
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  search values that are not in the set for  SequentialSearchSet :
# Time taken for search: 142.96257916100149 at searching absent number 0
# Time taken for search: 145.23402759099554 at searching absent number 20000
# Time taken for search: 170.02645861700148 at searching absent number 40000
# Time taken for search: 214.9867856839992 at searching absent number 60000
# Time taken for search: 270.18270463599765 at searching absent number 80000
# Time taken for search: 333.08160253100505 at searching absent number 100000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  search values that are not in the set for  BinarySearchTreeSet :
# Time taken for search: 0.33923380199848907 at searching absent number 0
# Time taken for search: 0.33626166700560134 at searching absent number 20000
# Time taken for search: 0.33364253499894403 at searching absent number 40000
# Time taken for search: 0.3426648210006533 at searching absent number 60000
# Time taken for search: 0.36238592600420816 at searching absent number 80000
# Time taken for search: 0.40003960100148106 at searching absent number 100000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  search values that are not in the set for  BalancedSearchTreeSet :
# Time taken for search: 0.3814927430066746 at searching absent number 0
# Time taken for search: 0.39114733699534554 at searching absent number 20000
# Time taken for search: 0.39954878199932864 at searching absent number 40000
# Time taken for search: 0.4133082859989372 at searching absent number 60000
# Time taken for search: 0.42953918999410234 at searching absent number 80000
# Time taken for search: 0.45468193299893755 at searching absent number 100000
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# Time taken with  search values that are not in the set for  BloomFilterSet :
# Time taken for search: 0.7160021050003706 at searching absent number 0
# False positive rate is:  0.0
# Time taken for search: 0.7130892630011658 at searching absent number 20000
# False positive rate is:  0.0
# Time taken for search: 0.7140580089981086 at searching absent number 40000
# False positive rate is:  0.0
# Time taken for search: 0.7159489709956688 at searching absent number 60000
# False positive rate is:  0.0
# Time taken for search: 0.713970127995708 at searching absent number 80000
# False positive rate is:  0.0
# Time taken for search: 0.7153712370054564 at searching absent number 100000
# False positive rate is:  0.0
# ----------------------------------------------------------------------------------------
